# %% [markdown]
# # Chapter 7 Exercises

# %% [markdown]
# ## Algorithm Workbench

# %% [markdown]
# ### Number 1

# %% [markdown]
# This question asks us to write a statement that creates a list with the following strings: 'Einstein', 'Newton', 'Copernicus', and 'Kepler'.

# %%
# Assign the variable scientists with a list of strings
scientists = ['Einstein', 'Newton', 'Copernicus', 'Kepler'] 

# ask user to print the variable scientists
print(scientists)
# Out:
# ['Einstein', 'Newton', 'Copernicus', 'Kepler']

# %% [markdown]
# since this code has minimal steps I'm going to explain what I did in a markdown. First I defined the variable scientists with a list of strings. I used [] to create the list. I separated each word by commas in the brackets. Each name inside the list is a string. I made the string using parenthesis and single quotes. Now the variable scientists is associated with the list that I created.

# %% [markdown]
# ### Number 14

# %% [markdown]
# This question asks us to say what the following code will print
# list1 = [40, 50, 60]
# list2 = [10, 20, 30]
# list3 = list1 + list2
# print(list3)

# %%
list1 = [40, 50, 60]
list2 = [10, 20, 30]
list3 = list1 + list2
print(list3)
# Out:
# [40, 50, 60, 10, 20, 30]

# %% [markdown]
# I can just insert the code into here and get the answer but I will explain how I knew what the result would be. The + sign means that it combines the elements of the lists, lists 1 and 2. This is using concatenation which the book taught me. List three using the + sign to combine list one and two and the print functiona asks user to print list3 which is those combined. That is why the result is the numbers in order from both lists, starting with list1.

# %% [markdown]
# ## Programming Exercises

# %% [markdown]
# ### Number 1

# %% [markdown]
# This question asks us to design a program that asks the user to enter a store’s sales for each day of the week. The amounts should be stored in a list. Use a loop to calculate the total sales for the week and display the result.

# %%
def main():

# Create empty list that contains the sales amounts
    sales = []

# tell user to enter sales for every day of the week
    for day in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']:
        amount = float(input(f"Enter sales for {day}: "))
        sales.append(amount)
    
# use a loop to calculate the total sales for the week
    total_sales = 0
    for amount in sales:
        total_sales += amount

    
# Show total sales for week
    print(f"Total sales for the week: {total_sales}")

#call the main function
if __name__ == '__main__':
    main()
# Out:
# Enter sales for Monday: 50.50
# Enter sales for Tuesday: 100.10
# Enter sales for Wednesday: 200
# Enter sales for Thursday: 120.10
# Enter sales for Friday: 50.45
# Enter sales for Saturday: 120.21
# Enter sales for Sunday: 130.10
# Total sales for the week: 771.4600000000002

# %% [markdown]
# ### Number 14

# %% [markdown]
# This question asks us to create a text file that contains your expenses for the the last month in specific categories

# %%
import matplotlib.pyplot as plt

def main():
    # read expensses from a file and store
    def read_expenses(filename):
        expenses = {}
        with open(filename) as file:
            for line in file:
                category, amount = line.strip().split(': ')
                expenses[category] = float(amount)
        return expenses
    
     # Function to plot a pie chart
    def plot_pie_chart(categories, amounts):
        plt.pie(amounts, labels=categories, autopct='%1.1f%%')
        plt.axis('equal')
        plt.title('Expense Distribution')
        plt.show()

    # specify the expenses file path
    expenses_file = 'expenses.txt'
    
      # Read expenses from file
    expenses = read_expenses(expenses_file)

    
    # set variables for categories and amounts
    categories = list(expenses.keys())
    amounts = list(expenses.values())
    
    #plot pie chart
    plot_pie_chart(categories, amounts)
    
    
    # Call the main function when the script is run 
if __name__ == '__main__':
    main()

# %% [markdown]
# ### Number 4

# %% [markdown]
# This question asks us to design a program that asks the user to enter a series of 20 numbers. The program should store the numbers in a list then display the following...

# %%
def main():
    # Make an empty list 
    numbers = []
   
     # Prompt the user to enter 20 numbers
    for i in range(20):
        number = float(input(f"Enter number {i+1}: "))
        numbers.append(number)
        
    # Find the lowest number
    lowest = min(numbers)
    
     # Find highest number
    highest = max(numbers)
    
     # Calculate total sum 
    total = sum(numbers)
    
       # Calculate average
    average = total / len(numbers)
    
     # Display the results
    print(f"Lowest number: {lowest}")
    print(f"Highest number: {highest}")
    print(f"Total sum: {total}")
    print(f"Average: {average}")

# Call the main function
if __name__ == '__main__':
    main()
# Out:
# Enter number 1: 2
# Enter number 2: 4
# Enter number 3: 5
# Enter number 4: 7
# Enter number 5: 8
# Enter number 6: 45
# Enter number 7: 65
# Enter number 8: 34
# Enter number 9: 56
# Enter number 10: 456
# Enter number 11: 45
# Enter number 12: 45
# Enter number 13: 3
# Enter number 14: 4
# Enter number 15: 5
# Enter number 16: 44
# Enter number 17: 56
# Enter number 18: 78
# Enter number 19: 98
# Enter number 20: 6
# Lowest number: 2.0
# Highest number: 456.0
# Total sum: 1066.0
# Average: 53.3
